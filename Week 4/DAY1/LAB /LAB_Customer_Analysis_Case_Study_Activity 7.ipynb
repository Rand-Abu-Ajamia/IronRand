# %% [markdown]
# # Activites List
#
# Here are some of the tasks you need to perform:
#
# ### Activity 1
#
# - Aggregate data into one Data Frame using Pandas.
# - Standardizing header names
# - Deleting and rearranging columns – delete the column customer as it is only a unique identifier for each row of data
# - Working with data types – Check the data types of all the columns and fix the incorrect ones (for ex. customer lifetime value and number of complaints )
# - Filtering data and Correcting typos – Filter the data in state and gender column to standardize the texts in those columns
# - Removing duplicates
# - Replacing null values – Replace missing values with means of the column (for numerical columns)
#
# ### Activity 2
#
# - Bucketing the data - Write a function to replace column "State" to different zones. California as West Region, Oregon as North West, and Washington as East, and Arizona and Nevada as Central
# - Standardizing the data – Use string functions to standardize the text data (lower case)
#
# ### Activity 3
#
# - Which columns are numerical?
# - Which columns are categorical?
# - Check and deal with NaN values. (Hint:Replacing null values – Replace missing values with means of the column (for numerical columns)).
# - Datetime format - Extract the months from the dataset and store in a separate column. Then filter the data to show only the information for the first quarter , ie. January, February and March. Hint: If data from March does not exist, consider only January and February.
# ### Activity 4
#
# - Show a plot of the total number of responses.
# - Show a plot of the response rate by the sales channel.
# - Show a plot of the response rate by the total claim amount.
# - Show a plot of the response rate by income.
# - Don't limit your creativity!  plot any interesting findings/insights that describe some interesting facts about your data set and its variables.
# - Plot the Correlation Heatmap.
# - Clean your notebook and make it a readible and presentable with a good documentation that summarizes the Data Cleaning, Exploration(including plots) Steps that you have performed.
#
# ### Activity 5
#
# - Check the data types of the columns. Get the numeric data into dataframe called `numerical` and categorical columns in a dataframe called `categoricals`.
# (You can use np.number and np.object to select the numerical data types and categorical data types respectively)
# - Now we will try to check the normality of the numerical variables visually
#   - Use seaborn library to construct distribution plots for the numerical variables
#   - Use Matplotlib to construct histograms
#   - Do the distributions for different numerical variables look like a normal distribution
# - For the numerical variables, check the multicollinearity between the features. Please note that we will use the column `total_claim_amount` later as the target variable.
# - Drop one of the two features that show a high correlation between them (greater than 0.9). Write code for both the correlation matrix and for seaborn heatmap. If there is no pair of features that have a high correlation, then do not drop any features

# %% [markdown]
# # Activity 1**

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max.row', 100) 
import statsmodels.api as sm

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
from sklearn.linear_model import LinearRegression

import scipy.stats as stats

# %%
file1 = pd.read_csv('Data/file1.csv')
file2= pd.read_csv('Data/file2.csv')
file3=pd.read_csv('Data/file3.csv')

# %%
#fetching new data with total number of responses & sales channel
df=pd.read_csv('Data/Data_Marketing_Customer_Analysis_Round2.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Customer', 'State', 'Customer Lifetime Value',
#        'Response', 'Coverage', 'Education', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size',
#        'Vehicle Type'],
#       dtype='object')

# %%
#standarise the header names
file1.rename(columns={'ST':'State', 'GENDER':'Gender'}, inplace=True)
file2.rename(columns={'ST':'State', 'GENDER':'Gender'}, inplace=True)

# %%
#Agregating data into a data frame called ca_da
ca_da=pd.concat([file1,file2,file3],axis=0).reset_index(drop=True)  #resetting the index

#adding the the new series with response sales channel
ca_da=pd.concat([ca_da, df[['Response','Sales Channel']]],axis=1)  

#first we use lower case 
ca_da.columns=[i.lower() for i in ca_da.columns]

# %%
# delete the column customer
ca_da.drop(columns=['customer'], inplace=True)

# %%
# Check the data types of all the columns and fix the incorrect ones
ca_da.dtypes
# Out:
# state                         object
# gender                        object
# education                     object
# customer lifetime value       object
# income                       float64
# monthly premium auto         float64
# number of open complaints     object
# policy type                   object
# vehicle class                 object
# total claim amount           float64
# response                      object
# sales channel                 object
# dtype: object

# %%
#change incorrect data types
ca_da['customer lifetime value'] =  pd.to_numeric(ca_da['customer lifetime value'], errors='coerce')
ca_da['number of open complaints']= pd.to_numeric(ca_da['number of open complaints'], errors='coerce')

# %%
ca_da.dtypes
# Out:
# state                         object
# gender                        object
# education                     object
# customer lifetime value      float64
# income                       float64
# monthly premium auto         float64
# number of open complaints    float64
# policy type                   object
# vehicle class                 object
# total claim amount           float64
# response                      object
# sales channel                 object
# dtype: object

# %%
ca_da
# Out:
#             state gender             education  customer lifetime value  \
# 0      Washington    NaN                Master                      NaN
# 1         Arizona      F              Bachelor                      NaN
# 2          Nevada      F              Bachelor                      NaN
# 3      California      M              Bachelor                      NaN
# 4      Washington      M  High School or Below                      NaN
# ...           ...    ...                   ...                      ...
# 12069  California      M              Bachelor             23405.987980
# 12070  California      F               College              3096.511217
# 12071  California      M              Bachelor              8163.890428
# 12072  California      M               College              7524.442436
# 12073  California      M               College              2611.836866
#
#         income  monthly premium auto  number of open complaints  \
# 0          0.0                1000.0                        NaN
# 1          0.0                  94.0                        NaN
# 2      48767.0                 108.0                        NaN
# 3          0.0                 106.0                        NaN
# 4      36357.0                  68.0                        NaN
# ...        ...                   ...                        ...
# 12069  71941.0                  73.0                        0.0
# 12070  21604.0                  79.0                        0.0
# 12071      0.0                  85.0                        3.0
# 12072  21941.0                  96.0                        0.0
# 12073      0.0                  77.0                        0.0
#
#           policy type  vehicle class  total claim amount response  \
# 0       Personal Auto  Four-Door Car            2.704934       No
# 1       Personal Auto  Four-Door Car         1131.464935       No
# 2       Personal Auto   Two-Door Car          566.472247       No
# 3      Corporate Auto            SUV          529.881344      Yes
# 4       Personal Auto  Four-Door Car           17.269323       No
# ...               ...            ...                 ...      ...
# 12069   Personal Auto  Four-Door Car          198.234764      NaN
# 12070  Corporate Auto  Four-Door Car          379.200000      NaN
# 12071  Corporate Auto  Four-Door Car          790.784983      NaN
# 12072   Personal Auto  Four-Door Car          691.200000      NaN
# 12073  Corporate Auto   Two-Door Car          369.600000      NaN
#
#       sales channel
# 0             Agent
# 1       Call Center
# 2       Call Center
# 3            Branch
# 4            Branch
# ...             ...
# 12069           NaN
# 12070           NaN
# 12071           NaN
# 12072           NaN
# 12073           NaN
#
# [12074 rows x 12 columns]

# %%
#filtering data for the Gender column
ca_da.gender.unique()
# Out:
# array([nan, 'F', 'M', 'Femal', 'Male', 'female'], dtype=object)

# %%
ca_da["gender"]= ca_da.gender.fillna ("U")   #filling the nan with U instead

# %%
ca_da.gender.unique()
# Out:
# array(['U', 'F', 'M', 'Femal', 'Male', 'female'], dtype=object)

# %%
#answer with a function - replacing the rest with either F or M
def clean_gender(x):
    if x in ['F','Female', 'Femal']: 
        return 'F'
    elif x in ['M','Male', 'male']: 
        return 'M'
    else: 
        return 'U'

# %%
#calling the function 
ca_da['gender']= list(map(clean_gender, ca_da['gender']))

# %%
ca_da.gender.value_counts()
# Out:
# F    4577
# M    4408
# U    3089
# Name: gender, dtype: int64

# %%
#Filter the data in state column to standardize the name of the states
ca_da['state'].value_counts(dropna=False)
# Out:
# California    3032
# NaN           2937
# Oregon        2601
# Arizona       1630
# Nevada         882
# Washington     768
# Cali           120
# AZ              74
# WA              30
# Name: state, dtype: int64

# %%
#replacing the names of overlapping states & and assign Unknown instead on NaN
ca_da.state.replace('Cali', 'California', inplace=True)
ca_da.state.replace('WA', 'Washington', inplace=True)
ca_da.state.replace('AZ', 'Arizona', inplace=True)
ca_da["state"]= ca_da.state.fillna ("Unknown")

# %%
ca_da['state'].value_counts(dropna=False)
# Out:
# California    3152
# Unknown       2937
# Oregon        2601
# Arizona       1704
# Nevada         882
# Washington     798
# Name: state, dtype: int64

# %%
ca_da['state'].value_counts(dropna=False)
# Out:
# California    3152
# Unknown       2937
# Oregon        2601
# Arizona       1704
# Nevada         882
# Washington     798
# Name: state, dtype: int64

# %%
#removing duplicates 
ca_da.drop_duplicates()
# Out:
#             state gender             education  customer lifetime value  \
# 0      Washington      U                Master                      NaN
# 1         Arizona      F              Bachelor                      NaN
# 2          Nevada      F              Bachelor                      NaN
# 3      California      M              Bachelor                      NaN
# 4      Washington      M  High School or Below                      NaN
# ...           ...    ...                   ...                      ...
# 12069  California      M              Bachelor             23405.987980
# 12070  California      F               College              3096.511217
# 12071  California      M              Bachelor              8163.890428
# 12072  California      M               College              7524.442436
# 12073  California      M               College              2611.836866
#
#         income  monthly premium auto  number of open complaints  \
# 0          0.0                1000.0                        NaN
# 1          0.0                  94.0                        NaN
# 2      48767.0                 108.0                        NaN
# 3          0.0                 106.0                        NaN
# 4      36357.0                  68.0                        NaN
# ...        ...                   ...                        ...
# 12069  71941.0                  73.0                        0.0
# 12070  21604.0                  79.0                        0.0
# 12071      0.0                  85.0                        3.0
# 12072  21941.0                  96.0                        0.0
# 12073      0.0                  77.0                        0.0
#
#           policy type  vehicle class  total claim amount response  \
# 0       Personal Auto  Four-Door Car            2.704934       No
# 1       Personal Auto  Four-Door Car         1131.464935       No
# 2       Personal Auto   Two-Door Car          566.472247       No
# 3      Corporate Auto            SUV          529.881344      Yes
# 4       Personal Auto  Four-Door Car           17.269323       No
# ...               ...            ...                 ...      ...
# 12069   Personal Auto  Four-Door Car          198.234764      NaN
# 12070  Corporate Auto  Four-Door Car          379.200000      NaN
# 12071  Corporate Auto  Four-Door Car          790.784983      NaN
# 12072   Personal Auto  Four-Door Car          691.200000      NaN
# 12073  Corporate Auto   Two-Door Car          369.600000      NaN
#
#       sales channel
# 0             Agent
# 1       Call Center
# 2       Call Center
# 3            Branch
# 4            Branch
# ...             ...
# 12069           NaN
# 12070           NaN
# 12071           NaN
# 12072           NaN
# 12073           NaN
#
# [9087 rows x 12 columns]

# %%
#Replace missing values with means of the column (for numerical columns), those columns are: 
ca_da._get_numeric_data()
# Out:
#        customer lifetime value   income  monthly premium auto  \
# 0                          NaN      0.0                1000.0
# 1                          NaN      0.0                  94.0
# 2                          NaN  48767.0                 108.0
# 3                          NaN      0.0                 106.0
# 4                          NaN  36357.0                  68.0
# ...                        ...      ...                   ...
# 12069             23405.987980  71941.0                  73.0
# 12070              3096.511217  21604.0                  79.0
# 12071              8163.890428      0.0                  85.0
# 12072              7524.442436  21941.0                  96.0
# 12073              2611.836866      0.0                  77.0
#
#        number of open complaints  total claim amount
# 0                            NaN            2.704934
# 1                            NaN         1131.464935
# 2                            NaN          566.472247
# 3                            NaN          529.881344
# 4                            NaN           17.269323
# ...                          ...                 ...
# 12069                        0.0          198.234764
# 12070                        0.0          379.200000
# 12071                        3.0          790.784983
# 12072                        0.0          691.200000
# 12073                        0.0          369.600000
#
# [12074 rows x 5 columns]

# %%
a_series = (ca_da != 0).any(axis=1)
ca_da = ca_da.loc[a_series]
ca_da           #I thought I deleted the zero values here ?
# Out:
#             state gender             education  customer lifetime value  \
# 0      Washington      U                Master                      NaN
# 1         Arizona      F              Bachelor                      NaN
# 2          Nevada      F              Bachelor                      NaN
# 3      California      M              Bachelor                      NaN
# 4      Washington      M  High School or Below                      NaN
# ...           ...    ...                   ...                      ...
# 12069  California      M              Bachelor             23405.987980
# 12070  California      F               College              3096.511217
# 12071  California      M              Bachelor              8163.890428
# 12072  California      M               College              7524.442436
# 12073  California      M               College              2611.836866
#
#         income  monthly premium auto  number of open complaints  \
# 0          0.0                1000.0                        NaN
# 1          0.0                  94.0                        NaN
# 2      48767.0                 108.0                        NaN
# 3          0.0                 106.0                        NaN
# 4      36357.0                  68.0                        NaN
# ...        ...                   ...                        ...
# 12069  71941.0                  73.0                        0.0
# 12070  21604.0                  79.0                        0.0
# 12071      0.0                  85.0                        3.0
# 12072  21941.0                  96.0                        0.0
# 12073      0.0                  77.0                        0.0
#
#           policy type  vehicle class  total claim amount response  \
# 0       Personal Auto  Four-Door Car            2.704934       No
# 1       Personal Auto  Four-Door Car         1131.464935       No
# 2       Personal Auto   Two-Door Car          566.472247       No
# 3      Corporate Auto            SUV          529.881344      Yes
# 4       Personal Auto  Four-Door Car           17.269323       No
# ...               ...            ...                 ...      ...
# 12069   Personal Auto  Four-Door Car          198.234764      NaN
# 12070  Corporate Auto  Four-Door Car          379.200000      NaN
# 12071  Corporate Auto  Four-Door Car          790.784983      NaN
# 12072   Personal Auto  Four-Door Car          691.200000      NaN
# 12073  Corporate Auto   Two-Door Car          369.600000      NaN
#
#       sales channel
# 0             Agent
# 1       Call Center
# 2       Call Center
# 3            Branch
# 4            Branch
# ...             ...
# 12069           NaN
# 12070           NaN
# 12071           NaN
# 12072           NaN
# 12073           NaN
#
# [12074 rows x 12 columns]

# %%
#beside NaN values, plently have zeros which we should delete 

ca_da= ca_da[ca_da.income !=0] # deleting all rows with zero values

# %%
#finding out how many null values do we have 
nulls_df=round(ca_da.isna().sum()/len(ca_da),4)*100
nulls_df
# Out:
# state                         0.00
# gender                        0.00
# education                    30.03
# customer lifetime value      46.33
# income                       30.03
# monthly premium auto         30.03
# number of open complaints    46.33
# policy type                  30.03
# vehicle class                30.03
# total claim amount           30.03
# response                     14.23
# sales channel                 8.68
# dtype: float64

# %%
#we don't have high number of null values in certain columns (high number would be a +70%)
nulls_df = nulls_df.reset_index()
nulls_df.columns = ['header_name', 'percent_nulls']
nulls_df
# Out:
#                   header_name  percent_nulls
# 0                       state           0.00
# 1                      gender           0.00
# 2                   education          30.03
# 3     customer lifetime value          46.33
# 4                      income          30.03
# 5        monthly premium auto          30.03
# 6   number of open complaints          46.33
# 7                 policy type          30.03
# 8               vehicle class          30.03
# 9          total claim amount          30.03
# 10                   response          14.23
# 11              sales channel           8.68

# %%
#let's assume that the customer lifetime value & number of open complaints has +70% of nulls 
nulls_columns=nulls_df[nulls_df['percent_nulls']>41]['header_name']
nulls_columns
# Out:
# 3      customer lifetime value
# 6    number of open complaints
# Name: header_name, dtype: object

# %% [markdown]
# #trying to replace nans using for function
# def replace_w_average(n):
#     for n in [ca_da._get_numeric_data()]:
#         ca_da[n].fillna(value=ca_da[n].mean(), inplace=True)
#         return ca_da[n]
#     replace_w_

# %%
ca_da.describe()    #checking whether to use the median or the mean
# Out:
#        customer lifetime value        income  monthly premium auto  \
# count              5249.000000   6843.000000           6843.000000
# mean               8147.381711  50510.292416            114.322665
# std                7045.407506  24290.459946            660.179537
# min                2119.894333  10037.000000             61.000000
# 25%                4091.934934  28494.000000             68.000000
# 50%                5815.261714  48115.000000             82.000000
# 75%                9035.671134  70263.000000            109.000000
# max               83325.381190  99981.000000          35354.000000
#
#        number of open complaints  total claim amount
# count                5249.000000         6843.000000
# mean                    0.380263          374.664285
# std                     0.914504          251.404565
# min                     0.000000            0.099007
# 25%                     0.000000          207.751860
# 50%                     0.000000          340.800000
# 75%                     0.000000          494.400000
# max                     5.000000         2893.239678

# %%
#replacing null values with the mean/median value in these 5 columns 

ca_da['customer lifetime value'].fillna(value=ca_da['customer lifetime value'].median(), inplace=True)
ca_da['income'].fillna(value=ca_da['income'].mean(), inplace=True)
ca_da['monthly premium auto'].fillna(value=ca_da['monthly premium auto'].median(), inplace=True)
ca_da['number of open complaints'].fillna(value=ca_da['number of open complaints'].mean(), inplace=True)
ca_da['total claim amount'].fillna(value=ca_da['total claim amount'].mean(), inplace=True)
# Out:
# /opt/anaconda3/envs/DA_env/lib/python3.8/site-packages/pandas/core/generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
#checking again how many null values there are 
nulls_df=round(ca_da.isna().sum()/len(ca_da),4)*100  
nulls_df
# Out:
# state                         0.00
# gender                        0.00
# education                    30.03
# customer lifetime value       0.00
# income                        0.00
# monthly premium auto          0.00
# number of open complaints     0.00
# policy type                  30.03
# vehicle class                30.03
# total claim amount            0.00
# response                     14.23
# sales channel                 8.68
# dtype: float64

# %% [markdown]
# **Activity 2**

# %%
ca_da.state
# Out:
# 2            Nevada
# 4        Washington
# 5            Oregon
# 6            Oregon
# 8            Oregon
#             ...
# 12067    California
# 12068    California
# 12069    California
# 12070    California
# 12072    California
# Name: state, Length: 9780, dtype: object

# %%
#Bucketing the data - Write a function to replace column "State" to different zones. 
#California as West Region, Oregon as North West, and Washington as East, and Arizona and Nevada as Central

zones = {
    "West Region": "California",
    "Nort West": "Oregon",
    "East": "Washington",
    "Cental": ["Arizona", "Nevada"]
}
ca_da["zones"] = (
    ca_da["state"]
    .apply(lambda x: [k for k in zones.keys() if x in zones[k]])
    .str[0]
    )
# Out:
# /var/folders/zg/6052zdgj2vs5d59k44zmww6m0000gn/T/ipykernel_4842/1902194210.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ca_da["zones"] = (

# %%
#Standardizing the data – Use string functions to standardize the text data (lower case)
ca_da["zones"] = ca_da["zones"].str.lower()
# Out:
# /var/folders/zg/6052zdgj2vs5d59k44zmww6m0000gn/T/ipykernel_4842/1982024438.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ca_da["zones"] = ca_da["zones"].str.lower()

# %%
ca_da
# Out:
#             state gender             education  customer lifetime value  \
# 2          Nevada      F              Bachelor              5815.261714
# 4      Washington      M  High School or Below              5815.261714
# 5          Oregon      F              Bachelor              5815.261714
# 6          Oregon      F               College              5815.261714
# 8          Oregon      M              Bachelor              5815.261714
# ...           ...    ...                   ...                      ...
# 12067  California      M               College              5032.165498
# 12068  California      F               College              4100.398533
# 12069  California      M              Bachelor             23405.987980
# 12070  California      F               College              3096.511217
# 12072  California      M               College              7524.442436
#
#         income  monthly premium auto  number of open complaints  \
# 2      48767.0                 108.0                   0.380263
# 4      36357.0                  68.0                   0.380263
# 5      62902.0                  69.0                   0.380263
# 6      55350.0                  67.0                   0.380263
# 8      14072.0                  71.0                   0.380263
# ...        ...                   ...                        ...
# 12067  66367.0                  64.0                   0.000000
# 12068  47761.0                 104.0                   0.000000
# 12069  71941.0                  73.0                   0.000000
# 12070  21604.0                  79.0                   0.000000
# 12072  21941.0                  96.0                   0.000000
#
#           policy type  vehicle class  total claim amount response  \
# 2       Personal Auto   Two-Door Car          566.472247       No
# 4       Personal Auto  Four-Door Car           17.269323       No
# 5       Personal Auto   Two-Door Car          159.383042      NaN
# 6      Corporate Auto  Four-Door Car          321.600000       No
# 8      Corporate Auto  Four-Door Car          511.200000      Yes
# ...               ...            ...                 ...      ...
# 12067   Personal Auto   Two-Door Car          307.200000      NaN
# 12068   Personal Auto  Four-Door Car          541.282007      NaN
# 12069   Personal Auto  Four-Door Car          198.234764      NaN
# 12070  Corporate Auto  Four-Door Car          379.200000      NaN
# 12072   Personal Auto  Four-Door Car          691.200000      NaN
#
#       sales channel        zones
# 2       Call Center       cental
# 4            Branch         east
# 5             Agent    nort west
# 6            Branch    nort west
# 8            Branch    nort west
# ...             ...          ...
# 12067           NaN  west region
# 12068           NaN  west region
# 12069           NaN  west region
# 12070           NaN  west region
# 12072           NaN  west region
#
# [9780 rows x 13 columns]

# %% [markdown]
# **Activity 3**

# %%
#numerical columns
ca_da._get_numeric_data()
# Out:
#        customer lifetime value   income  monthly premium auto  \
# 2                  5815.261714  48767.0                 108.0
# 4                  5815.261714  36357.0                  68.0
# 5                  5815.261714  62902.0                  69.0
# 6                  5815.261714  55350.0                  67.0
# 8                  5815.261714  14072.0                  71.0
# ...                        ...      ...                   ...
# 12067              5032.165498  66367.0                  64.0
# 12068              4100.398533  47761.0                 104.0
# 12069             23405.987980  71941.0                  73.0
# 12070              3096.511217  21604.0                  79.0
# 12072              7524.442436  21941.0                  96.0
#
#        number of open complaints  total claim amount
# 2                       0.380263          566.472247
# 4                       0.380263           17.269323
# 5                       0.380263          159.383042
# 6                       0.380263          321.600000
# 8                       0.380263          511.200000
# ...                          ...                 ...
# 12067                   0.000000          307.200000
# 12068                   0.000000          541.282007
# 12069                   0.000000          198.234764
# 12070                   0.000000          379.200000
# 12072                   0.000000          691.200000
#
# [9780 rows x 5 columns]

# %%
ca_da_category = ca_da.select_dtypes(include=['object'])  
ca_da_category
# Out:
#             state gender             education     policy type  vehicle class  \
# 2          Nevada      F              Bachelor   Personal Auto   Two-Door Car
# 4      Washington      M  High School or Below   Personal Auto  Four-Door Car
# 5          Oregon      F              Bachelor   Personal Auto   Two-Door Car
# 6          Oregon      F               College  Corporate Auto  Four-Door Car
# 8          Oregon      M              Bachelor  Corporate Auto  Four-Door Car
# ...           ...    ...                   ...             ...            ...
# 12067  California      M               College   Personal Auto   Two-Door Car
# 12068  California      F               College   Personal Auto  Four-Door Car
# 12069  California      M              Bachelor   Personal Auto  Four-Door Car
# 12070  California      F               College  Corporate Auto  Four-Door Car
# 12072  California      M               College   Personal Auto  Four-Door Car
#
#       response sales channel        zones
# 2           No   Call Center       cental
# 4           No        Branch         east
# 5          NaN         Agent    nort west
# 6           No        Branch    nort west
# 8          Yes        Branch    nort west
# ...        ...           ...          ...
# 12067      NaN           NaN  west region
# 12068      NaN           NaN  west region
# 12069      NaN           NaN  west region
# 12070      NaN           NaN  west region
# 12072      NaN           NaN  west region
#
# [9780 rows x 8 columns]

# %%
#Check and deal with NaN values. this was done previously, but since these two columns were added later :
ca_da['sales channel'].fillna(value='Unknown', inplace=True)
ca_da['response'].fillna(value='Y/N', inplace=True)
# Out:
# /opt/anaconda3/envs/DA_env/lib/python3.8/site-packages/pandas/core/generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
#Datetime format - Extract the months from the dataset and store in a separate column. 
#Then filter the data to show only the information for the first quarter , ie. January, February and March. 
#Hint: If data from March does not exist, consider only January and February.

# %% [markdown]
# **Activity 4**

# %%
ca_da.columns
# Out:
# Index(['state', 'gender', 'education', 'customer lifetime value', 'income',
#        'monthly premium auto', 'number of open complaints', 'policy type',
#        'vehicle class', 'total claim amount', 'response', 'sales channel',
#        'zones'],
#       dtype='object')

# %%
# importing matplotlib & seaborn

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Show a plot of the total number of responses.

#we first need to count the responses 
response = ca_da['response'].value_counts()
#plotting a bar plot 
ax1=sns.barplot(x=response.index ,y =response);
#adding a title
ax1.set_title("Total number of responses", fontweight='bold');

# %%
#Show a plot of the response rate by the sales channel.

#we first define the axis 
#y= the count of responses 
#x=response(as yes/no)
#the best fitting plot is a countplot

ax2= sns.countplot(data=ca_da, x="response", hue="sales channel");
#adding a title
ax2.set_title("Response rate per sales channel", fontweight='bold');

# %%
ca_da["total claim amount"]
# Out:
# 2        566.472247
# 4         17.269323
# 5        159.383042
# 6        321.600000
# 8        511.200000
#             ...
# 12067    307.200000
# 12068    541.282007
# 12069    198.234764
# 12070    379.200000
# 12072    691.200000
# Name: total claim amount, Length: 9780, dtype: float64

# %%
#Show a plot of the response rate by the total claim amount
fig,ax=plt.subplots(figsize=(14,6))

sns.histplot(data=ca_da, x="total claim amount", ax=ax, hue='response');
ax.set_title("Response rate by total claim amount", fontweight='bold');

# %%
#Show a plot of the response rate by income.

ax4=sns.barplot(data=ca_da, x='response' ,y ="income");
ax4.set_title("Response rate by income", fontsize=16);

# %%
#Don't limit your creativity! plot any interesting findings/insights that describe some interesting facts about your data set and its variables.
#Plot the Correlation Heatmap.

# %%
#Plot the Correlation Heatmap.
#showing the correlation between the different variables 
corr=ca_da.corr()

# Setting up the plot 
f, ax = plt.subplots(figsize=(8, 4))

# Draw the heatmap
heat_map=sns.heatmap(corr, annot=True, cmap='seismic', center=0)

# %% [markdown]
# ### Activity 5
#
# - Check the data types of the columns. Get the numeric data into dataframe called `numerical` and categorical columns in a dataframe called `categoricals`.
# (You can use np.number and np.object to select the numerical data types and categorical data types respectively)
# - Now we will try to check the normality of the numerical variables visually
#   - Use seaborn library to construct distribution plots for the numerical variables
#   - Use Matplotlib to construct histograms
#   - Do the distributions for different numerical variables look like a normal distribution
# - For the numerical variables, check the multicollinearity between the features. Please note that we will use the column `total_claim_amount` later as the target variable.
# - Drop one of the two features that show a high correlation between them (greater than 0.9). Write code for both the correlation matrix and for seaborn heatmap. If there is no pair of features that have a high correlation, then do not drop any features

# %% [markdown]
# ## Activity 6
#
# - X-y split

# %% [raw]
# ca_da.hist(figsize=(14,14))

# %%
ca_da
# Out:
#             state gender             education  customer lifetime value  \
# 2          Nevada      F              Bachelor              5815.261714
# 4      Washington      M  High School or Below              5815.261714
# 5          Oregon      F              Bachelor              5815.261714
# 6          Oregon      F               College              5815.261714
# 8          Oregon      M              Bachelor              5815.261714
# ...           ...    ...                   ...                      ...
# 12067  California      M               College              5032.165498
# 12068  California      F               College              4100.398533
# 12069  California      M              Bachelor             23405.987980
# 12070  California      F               College              3096.511217
# 12072  California      M               College              7524.442436
#
#         income  monthly premium auto  number of open complaints  \
# 2      48767.0                 108.0                   0.380263
# 4      36357.0                  68.0                   0.380263
# 5      62902.0                  69.0                   0.380263
# 6      55350.0                  67.0                   0.380263
# 8      14072.0                  71.0                   0.380263
# ...        ...                   ...                        ...
# 12067  66367.0                  64.0                   0.000000
# 12068  47761.0                 104.0                   0.000000
# 12069  71941.0                  73.0                   0.000000
# 12070  21604.0                  79.0                   0.000000
# 12072  21941.0                  96.0                   0.000000
#
#           policy type  vehicle class  total claim amount response  \
# 2       Personal Auto   Two-Door Car          566.472247       No
# 4       Personal Auto  Four-Door Car           17.269323       No
# 5       Personal Auto   Two-Door Car          159.383042      Y/N
# 6      Corporate Auto  Four-Door Car          321.600000       No
# 8      Corporate Auto  Four-Door Car          511.200000      Yes
# ...               ...            ...                 ...      ...
# 12067   Personal Auto   Two-Door Car          307.200000      Y/N
# 12068   Personal Auto  Four-Door Car          541.282007      Y/N
# 12069   Personal Auto  Four-Door Car          198.234764      Y/N
# 12070  Corporate Auto  Four-Door Car          379.200000      Y/N
# 12072   Personal Auto  Four-Door Car          691.200000      Y/N
#
#       sales channel        zones
# 2       Call Center       cental
# 4            Branch         east
# 5             Agent    nort west
# 6            Branch    nort west
# 8            Branch    nort west
# ...             ...          ...
# 12067       Unknown  west region
# 12068       Unknown  west region
# 12069       Unknown  west region
# 12070       Unknown  west region
# 12072       Unknown  west region
#
# [9780 rows x 13 columns]

# %% [markdown]
# ***x-y split***

# %%
ca_da.rename(columns={'total claim amount':'total_claim_amount'}, inplace=True)
# Out:
# /opt/anaconda3/envs/DA_env/lib/python3.8/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
X=ca_da.drop('total_claim_amount', axis=1)
y=ca_da.total_claim_amount    #ca_da['total claim amount']

# %%
X=X._get_numeric_data()
X
# Out:
#        customer lifetime value   income  monthly premium auto  \
# 2                  5815.261714  48767.0                 108.0
# 4                  5815.261714  36357.0                  68.0
# 5                  5815.261714  62902.0                  69.0
# 6                  5815.261714  55350.0                  67.0
# 8                  5815.261714  14072.0                  71.0
# ...                        ...      ...                   ...
# 12067              5032.165498  66367.0                  64.0
# 12068              4100.398533  47761.0                 104.0
# 12069             23405.987980  71941.0                  73.0
# 12070              3096.511217  21604.0                  79.0
# 12072              7524.442436  21941.0                  96.0
#
#        number of open complaints
# 2                       0.380263
# 4                       0.380263
# 5                       0.380263
# 6                       0.380263
# 8                       0.380263
# ...                          ...
# 12067                   0.000000
# 12068                   0.000000
# 12069                   0.000000
# 12070                   0.000000
# 12072                   0.000000
#
# [9780 rows x 4 columns]

# %%
y
# Out:
# 2        566.472247
# 4         17.269323
# 5        159.383042
# 6        321.600000
# 8        511.200000
#             ...
# 12067    307.200000
# 12068    541.282007
# 12069    198.234764
# 12070    379.200000
# 12072    691.200000
# Name: total_claim_amount, Length: 9780, dtype: float64

# %%
ax=sns.displot(x=ca_da.income, bins=20)

# %% [markdown]
# - Normalize (numerical).

# %%
from sklearn.preprocessing import StandardScaler

# %%
X_scaled=StandardScaler().fit_transform(X)
X_scaled.shape
# Out:
# (9780, 4)

# %%
type(X_scaled)
# Out:
# numpy.ndarray

# %%
X_scaled
# Out:
# array([[-2.36592342e-01, -8.58049603e-02,  6.12627097e-03,
#         -8.28642315e-17],
#        [-2.36592342e-01, -6.96625926e-01, -6.62872293e-02,
#         -8.28642315e-17],
#        [-2.36592342e-01,  6.09920612e-01, -6.44768918e-02,
#         -8.28642315e-17],
#        ...,
#        [ 3.08843976e+00,  1.05482075e+00, -5.72355417e-02,
#         -5.67637184e-01],
#        [-7.50495665e-01, -1.42276950e+00, -4.63735167e-02,
#         -5.67637184e-01],
#        [ 8.64802070e-02, -1.40618234e+00, -1.55977791e-02,
#         -5.67637184e-01]])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test=train_test_split(X_scaled, y, test_size=.20)

# %%
X_train
# Out:
# array([[ 7.29580369e-01, -1.03816393e+00,  3.06642297e-01,
#         -5.67637184e-01],
#        [-2.36592342e-01,  3.58123083e-16, -4.09425042e-02,
#         -8.28642315e-17],
#        [-2.36592342e-01,  3.58123083e-16, -4.09425042e-02,
#         -8.28642315e-17],
#        ...,
#        [ 6.26693116e-01, -8.70668065e-01,  4.41433586e-02,
#         -5.67637184e-01],
#        [-2.36592342e-01,  3.58123083e-16, -4.09425042e-02,
#         -8.28642315e-17],
#        [-2.36592342e-01,  3.58123083e-16, -4.09425042e-02,
#         -8.28642315e-17]])

# %% [markdown]
# - One Hot/Label Encoding (categorical)

# %%
ca_da_category
# Out:
#             state gender             education     policy type  vehicle class  \
# 2          Nevada      F              Bachelor   Personal Auto   Two-Door Car
# 4      Washington      M  High School or Below   Personal Auto  Four-Door Car
# 5          Oregon      F              Bachelor   Personal Auto   Two-Door Car
# 6          Oregon      F               College  Corporate Auto  Four-Door Car
# 8          Oregon      M              Bachelor  Corporate Auto  Four-Door Car
# ...           ...    ...                   ...             ...            ...
# 12067  California      M               College   Personal Auto   Two-Door Car
# 12068  California      F               College   Personal Auto  Four-Door Car
# 12069  California      M              Bachelor   Personal Auto  Four-Door Car
# 12070  California      F               College  Corporate Auto  Four-Door Car
# 12072  California      M               College   Personal Auto  Four-Door Car
#
#       response sales channel        zones
# 2           No   Call Center       cental
# 4           No        Branch         east
# 5          NaN         Agent    nort west
# 6           No        Branch    nort west
# 8          Yes        Branch    nort west
# ...        ...           ...          ...
# 12067      NaN           NaN  west region
# 12068      NaN           NaN  west region
# 12069      NaN           NaN  west region
# 12070      NaN           NaN  west region
# 12072      NaN           NaN  west region
#
# [9780 rows x 8 columns]

# %%
# generating binary values using dummies 
dum_ca_da_category=pd.get_dummies(ca_da_category, columns=['state','gender','education','policy type', 'vehicle class','response','sales channel', 'zones'])

# %%
dum_ca_da_category
# Out:
#        state_Arizona  state_California  state_Nevada  state_Oregon  \
# 2                  0                 0             1             0
# 4                  0                 0             0             0
# 5                  0                 0             0             1
# 6                  0                 0             0             1
# 8                  0                 0             0             1
# ...              ...               ...           ...           ...
# 12067              0                 1             0             0
# 12068              0                 1             0             0
# 12069              0                 1             0             0
# 12070              0                 1             0             0
# 12072              0                 1             0             0
#
#        state_Unknown  state_Washington  gender_F  gender_M  gender_U  \
# 2                  0                 0         1         0         0
# 4                  0                 1         0         1         0
# 5                  0                 0         1         0         0
# 6                  0                 0         1         0         0
# 8                  0                 0         0         1         0
# ...              ...               ...       ...       ...       ...
# 12067              0                 0         0         1         0
# 12068              0                 0         1         0         0
# 12069              0                 0         0         1         0
# 12070              0                 0         1         0         0
# 12072              0                 0         0         1         0
#
#        education_Bachelor  ...  response_No  response_Yes  \
# 2                       1  ...            1             0
# 4                       0  ...            1             0
# 5                       1  ...            0             0
# 6                       0  ...            1             0
# 8                       1  ...            0             1
# ...                   ...  ...          ...           ...
# 12067                   0  ...            0             0
# 12068                   0  ...            0             0
# 12069                   1  ...            0             0
# 12070                   0  ...            0             0
# 12072                   0  ...            0             0
#
#        sales channel_Agent  sales channel_Branch  sales channel_Call Center  \
# 2                        0                     0                          1
# 4                        0                     1                          0
# 5                        1                     0                          0
# 6                        0                     1                          0
# 8                        0                     1                          0
# ...                    ...                   ...                        ...
# 12067                    0                     0                          0
# 12068                    0                     0                          0
# 12069                    0                     0                          0
# 12070                    0                     0                          0
# 12072                    0                     0                          0
#
#        sales channel_Web  zones_cental  zones_east  zones_nort west  \
# 2                      0             1           0                0
# 4                      0             0           1                0
# 5                      0             0           0                1
# 6                      0             0           0                1
# 8                      0             0           0                1
# ...                  ...           ...         ...              ...
# 12067                  0             0           0                0
# 12068                  0             0           0                0
# 12069                  0             0           0                0
# 12070                  0             0           0                0
# 12072                  0             0           0                0
#
#        zones_west region
# 2                      0
# 4                      0
# 5                      0
# 6                      0
# 8                      0
# ...                  ...
# 12067                  1
# 12068                  1
# 12069                  1
# 12070                  1
# 12072                  1
#
# [9780 rows x 34 columns]

# %%
#merging with main dataframe on key values 
ca_da_category=ca_da.join(dum_ca_da_category)

# %% [markdown]
#  # Activity 7

# %% [markdown]
# ## Linear Regression
# ### Train-test split

# %%
ca_da._get_numeric_data()
# Out:
#        customer lifetime value   income  monthly premium auto  \
# 2                  5815.261714  48767.0                 108.0
# 4                  5815.261714  36357.0                  68.0
# 5                  5815.261714  62902.0                  69.0
# 6                  5815.261714  55350.0                  67.0
# 8                  5815.261714  14072.0                  71.0
# ...                        ...      ...                   ...
# 12067              5032.165498  66367.0                  64.0
# 12068              4100.398533  47761.0                 104.0
# 12069             23405.987980  71941.0                  73.0
# 12070              3096.511217  21604.0                  79.0
# 12072              7524.442436  21941.0                  96.0
#
#        number of open complaints  total_claim_amount
# 2                       0.380263          566.472247
# 4                       0.380263           17.269323
# 5                       0.380263          159.383042
# 6                       0.380263          321.600000
# 8                       0.380263          511.200000
# ...                          ...                 ...
# 12067                   0.000000          307.200000
# 12068                   0.000000          541.282007
# 12069                   0.000000          198.234764
# 12070                   0.000000          379.200000
# 12072                   0.000000          691.200000
#
# [9780 rows x 5 columns]

# %%
X_train
# Out:
# array([[ 7.29580369e-01, -1.03816393e+00,  3.06642297e-01,
#         -5.67637184e-01],
#        [-2.36592342e-01,  3.58123083e-16, -4.09425042e-02,
#         -8.28642315e-17],
#        [-2.36592342e-01,  3.58123083e-16, -4.09425042e-02,
#         -8.28642315e-17],
#        ...,
#        [ 6.26693116e-01, -8.70668065e-01,  4.41433586e-02,
#         -5.67637184e-01],
#        [-2.36592342e-01,  3.58123083e-16, -4.09425042e-02,
#         -8.28642315e-17],
#        [-2.36592342e-01,  3.58123083e-16, -4.09425042e-02,
#         -8.28642315e-17]])

# %% [markdown]
# **using statsmodel**

# %%
X_train = sm.add_constant(X_train) #adding a constant
model = sm.OLS(y_train, X_train).fit()
predictions = model.predict(X_train) 

print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     total_claim_amount   R-squared:                       0.106
# Model:                            OLS   Adj. R-squared:                  0.106
# Method:                 Least Squares   F-statistic:                     232.5
# Date:                Tue, 09 Nov 2021   Prob (F-statistic):          6.89e-189
# Time:                        18:45:31   Log-Likelihood:                -52630.
# No. Observations:                7824   AIC:                         1.053e+05
# Df Residuals:                    7819   BIC:                         1.053e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        376.8301      2.283    165.035      0.000     372.354     381.306
# x1            50.6941      2.260     22.435      0.000      46.265      55.124
# x2           -46.6687      2.292    -20.363      0.000     -51.161     -42.176
# x3             0.6455      2.044      0.316      0.752      -3.361       4.652
# x4            -1.0715      2.281     -0.470      0.639      -5.543       3.400
# ==============================================================================
# Omnibus:                     3573.280   Durbin-Watson:                   1.965
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            45703.584
# Skew:                           1.849   Prob(JB):                         0.00
# Kurtosis:                      14.248   Cond. No.                         1.13
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# **Using Scikit learn**

# %%
X_train, X_test, y_train, y_test=train_test_split(X_scaled, y, test_size=.20)

# %%
model=LinearRegression()    # model
model.fit(X_train, y_train) #model train
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([ 45.2565618 , -45.29134581,   0.6452528 ,  -2.11510518])

# %%
y_prediction=model.predict(X_test)   # model prediction
##y_pred_train=model.predict(X_train)

# %%
y_prediction
# Out:
# array([363.68285019, 388.05491472, 492.3384873 , ..., 455.50443511,
#        249.31186154, 356.49080817])

# %%
result=pd.DataFrame({'y_test':y_test, "y_prediction":y_predictions})
result
# Out:
#            y_test  y_prediction
# 1585   374.664285    363.682850
# 8583   292.800000    388.054915
# 7545    70.031111    492.338487
# 2558   374.664285    363.682850
# 11066  131.515739    436.433935
# ...           ...           ...
# 11393  109.906628    415.553231
# 1815   374.664285    363.682850
# 7010    19.464450    455.504435
# 11725   34.235959    249.311862
# 8111   480.000000    356.490808
#
# [1956 rows x 2 columns]

# %%
#now we plot the predicted values vs real ones (y)
plt.scatter(y_test, y_predictions)
plt.xlabel("y_test")
plt.ylabel("y_prediction")
plt.title("Predections vs real values in test set");

# %%
#plotting a histogram of the errors (residuals) to show the homogeneity of variance
plt.hist(y_test-y_predictions) #the difference is the error
plt.xlabel("Test y-y_predicted")
plt.title("Test Set Residual histogram");

# %% [markdown]
# ### Apply linear regression with scipy

# %%
print (y_prediction)
# Out:
# 0       363.682850
# 1       388.054915
# 2       492.338487
# 3       363.682850
# 4       436.433935
#            ...
# 1951    415.553231
# 1952    363.682850
# 1953    455.504435
# 1954    249.311862
# 1955    356.490808
# Length: 1956, dtype: float64

# %%
y_prediction=pd.Series(y_prediction)
print(y)
# Out:
# 2        566.472247
# 4         17.269323
# 5        159.383042
# 6        321.600000
# 8        511.200000
#             ...
# 12067    307.200000
# 12068    541.282007
# 12069    198.234764
# 12070    379.200000
# 12072    691.200000
# Name: total_claim_amount, Length: 9780, dtype: float64

# %%
Data=pd.concat([X,y,y_prediction])

Data
# Out:
#                0  customer lifetime value   income  monthly premium auto  \
# 2            NaN              5815.261714  48767.0                 108.0
# 4            NaN              5815.261714  36357.0                  68.0
# 5            NaN              5815.261714  62902.0                  69.0
# 6            NaN              5815.261714  55350.0                  67.0
# 8            NaN              5815.261714  14072.0                  71.0
# ...          ...                      ...      ...                   ...
# 1951  415.553231                      NaN      NaN                   NaN
# 1952  363.682850                      NaN      NaN                   NaN
# 1953  455.504435                      NaN      NaN                   NaN
# 1954  249.311862                      NaN      NaN                   NaN
# 1955  356.490808                      NaN      NaN                   NaN
#
#       number of open complaints
# 2                      0.380263
# 4                      0.380263
# 5                      0.380263
# 6                      0.380263
# 8                      0.380263
# ...                         ...
# 1951                        NaN
# 1952                        NaN
# 1953                        NaN
# 1954                        NaN
# 1955                        NaN
#
# [21516 rows x 5 columns]

# %%
sns.regplot(x='y', y='y_prediction',data=Data, scatter_kws={"color", "blue"}, line_kws={"color": "black"})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/envs/DA_env/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /opt/anaconda3/envs/DA_env/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/anaconda3/envs/DA_env/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'y'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/zg/6052zdgj2vs5d59k44zmww6m0000gn/T/ipykernel_4842/4253302393.py in <module>
# ----> 1 sns.regplot(x='y', y='y_prediction',data=Data, scatter_kws={"color", "blue"}, line_kws={"color": "black"})
#
# /opt/anaconda3/envs/DA_env/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /opt/anaconda3/envs/DA_env/lib/python3.8/site-packages/seaborn/regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     849 ):
#     850
# --> 851     plotter = _RegressionPlotter(x, y, data, x_estimator, x_bins, x_ci,
#     852                                  scatter, fit_reg, ci, n_boot, units, seed,
#     853                                  order, logistic, lowess, robust, logx,
#
# /opt/anaconda3/envs/DA_env/lib/python3.8/site-packages/seaborn/regression.py in __init__(self, x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, color, label)
#     107
#     108         # Extract the data vals from the arguments or passed dataframe
# --> 109         self.establish_variables(data, x=x, y=y, units=units,
#     110                                  x_partial=x_partial, y_partial=y_partial)
#     111
#
# /opt/anaconda3/envs/DA_env/lib/python3.8/site-packages/seaborn/regression.py in establish_variables(self, data, **kws)
#      44         for var, val in kws.items():
#      45             if isinstance(val, str):
# ---> 46                 vector = data[val]
#      47             elif isinstance(val, list):
#      48                 vector = np.asarray(val)
#
# /opt/anaconda3/envs/DA_env/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /opt/anaconda3/envs/DA_env/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'y'

# %% [markdown]
# ## Model validation
# ### MSE

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame
