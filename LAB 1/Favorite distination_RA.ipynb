# %% [markdown]
# # Introduction
#
# This notebook is designed to describer your favorite holiday distination

# %% [markdown]
# # Function 1

# %%
input ("please enter the person's name")

# %% [markdown]
# ![20151211_122924.jpg](attachment:20151211_122924.jpg)

# %% [markdown]
# # Function 2

# %%
input ("please enter your holiday prefernce")
# Out:
# please enter your holiday prefernce Athens
# ' Athens'

# %% [markdown]
# # Athens

# %% [markdown]
# ![acropolis-city-state-Greece-Athens.jpeg](attachment:acropolis-city-state-Greece-Athens.jpeg)

# %% [markdown]
# ## Picture of Athens

# %% [markdown]
# ## *Top three things to do in Athens*
#
# <span style="color:blue"> + Visiting the amazing Acropolis Museum and learn about the rich history of humans text</span>
#
# <span style="color:red"> + Enjoying a walking tour in the beautiful city text</span>
#
# <span style="color:green"> + Visiting the nearby beaches, enjoying the sun text</span>

# %% [markdown]
# ## A day in the life of an ancient Athenian

# %% [markdown]
# [![A day in the life of an ancient Athenian](https://upload.wikimedia.org/wikipedia/commons/f/f1/Discurso_funebre_pericles.PNG)](https://www.youtube.com/watch?v=ar8S6virCwM)
